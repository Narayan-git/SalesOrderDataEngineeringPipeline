# %%
# ============================================================================
# DATABRICKS MEDALLION ARCHITECTURE - SCHEMA DEFINITIONS
# ============================================================================
# These schema names define the three-layer data architecture pattern
# All downstream notebooks import these definitions to ensure consistency

# BRONZE LAYER: Raw data ingestion (minimal transformation)
# - Captures original data state with full audit trail
# - Minimal data cleaning
# - Change Data Feed (CDF) enabled for tracking
bronze_schema = "bronze"

# SILVER LAYER: Cleaned and conformed data (single source of truth)
# - Deduplicated records
# - Standardized formats
# - Applied business rules
# - Ready for analytics team use
silver_schema = "silver"

# GOLD LAYER: Business-ready analytics data
# - Aggregated to appropriate business grain
# - Enriched with business logic
# - Optimized for performance
# - Powers dashboards and BI tools
gold_schema = "gold"

# ============================================================================
# CONFIGURATION NOTES:
# - Modify these values only when changing environment (dev → prod)
# - Always propagate changes to all dependent notebooks
# - Schema names should match actual Databricks schema names
# ============================================================================
